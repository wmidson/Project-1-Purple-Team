# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pathlib import Path

# %%
# File to Load (Remember to Change These)
census_csv = Path("Resources/usethisfile_ACSDP5YSPT2021.DP03-Data.csv")
# print(census_csv)
readmissions_csv = Path("Resources/USETHIS_cms_readmission.csv")
# print(readmissions_csv)

# %%
readmission_data = pd.read_csv(readmissions_csv)
readmission_data = readmission_data.rename(columns={'area_type': 'Area', 'primary_race': 'Race', 'value': '% Readmission'})
readmission_data.set_index("state", inplace = True)

# readmission_data = df.sort_values(by='column_name', ascending=True)
readmission_data.head(15)
# Out:
#          year            county   Area   Race  % Readmission
# state
# ALABAMA  2020    Autauga County  Urban  White             15
# ALABAMA  2020    Baldwin County  Rural  White             16
# ALABAMA  2020    Barbour County  Rural  White             16
# ALABAMA  2020       Bibb County  Urban  White             15
# ALABAMA  2020    Bullock County  Rural  White             16
# ALABAMA  2020     Butler County  Rural  White             15
# ALABAMA  2020    Calhoun County  Urban  White             15
# ALABAMA  2020   Cherokee County  Rural  White             15
# ALABAMA  2020    Choctaw County  Rural  White             15
# ALABAMA  2020     Clarke County  Rural  White             16
# ALABAMA  2020       Clay County  Rural  White             17
# ALABAMA  2020     Coffee County  Rural  White             16
# ALABAMA  2020    Colbert County  Urban  White             15
# ALABAMA  2020    Conecuh County  Rural  White             17
# ALABAMA  2020  Covington County  Rural  White             17

# %%
avg_percentage_readmission = readmission_data.groupby(["state","Race"])["% Readmission"].mean()
avg_percentage_readmission.to_csv("Output/Average_Readmission_Clean.csv", header=True)
avg_percentage_readmission
# Out:
# state    Race
# ALABAMA  American Indian/Alaska native    15.767442
#          Asian/Pacific islander           15.480000
#          Black                            15.403689
#          Hispanic                         15.300654
#          Other                            15.555556
#                                             ...
# WYOMING  Asian/Pacific islander           15.181818
#          Black                            15.000000
#          Hispanic                         14.988764
#          Other                            15.062500
#          White                            15.242424
# Name: % Readmission, Length: 308, dtype: float64

# %%
#For Later use
census_data = pd.read_csv(census_csv)

census_data.head()
# Out:
#         GEO_ID                  NAME           POPGROUP  \
# 0    Geography  Geographic Area Name  Race/Ethnic Group
# 1  0400000US02                Alaska                  2
# 2  0400000US02                Alaska                  4
# 3  0400000US02                Alaska                  6
# 4  0400000US02                Alaska                 12
#
#                             POPGROUP_LABEL  \
# 0                        Population Groups
# 1                              White alone
# 2          Black or African American alone
# 3  American Indian and Alaska Native alone
# 4                              Asian alone
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                             375399
# 2                                              19205
# 3                                              76502
# 4                                              38486
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               1419
# 2                                                698
# 3                                               1244
# 4                                                747
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                             254239
# 2                                              14351
# 3                                              42802
# 4                                              28061
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               2268
# 2                                                778
# 3                                               1147
# 4                                                906
#
#                                           DP03_0003E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                             239424
# 2                                              12108
# 3                                              42595
# 4                                              27570
#
#                                           DP03_0003M  ...  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...  ...
# 1                                               2236  ...
# 2                                                844  ...
# 3                                               1137  ...
# 4                                                951  ...
#
#                                          DP03_0133PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                7.1
# 2                                                8.9
# 3                                               21.5
# 4                                                8.7
#
#                                          DP03_0133PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.4
# 2                                                2.1
# 3                                                1.1
# 4                                                1.7
#
#                                          DP03_0134PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                7.2
# 2                                                9.2
# 3                                               22.9
# 4                                                8.7
#
#                                          DP03_0134PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.4
# 2                                                2.4
# 3                                                1.3
# 4                                                1.9
#
#                                          DP03_0135PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                6.5
# 2                                                6.3
# 3                                                 13
# 4                                                8.7
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.8
# 2                                                3.6
# 3                                                2.2
# 4                                                3.4
#
#                                          DP03_0136PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                4.5
# 2                                                9.7
# 3                                               20.6
# 4                                                7.1
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.4
# 2                                                  4
# 3                                                1.3
# 4                                                2.7
#
#                                          DP03_0137PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                               16.4
# 2                                               16.2
# 3                                               38.6
# 4                                               19.8
#
#                                          DP03_0137PM
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                  1
# 2                                                4.6
# 3                                                2.6
# 4                                                3.5
#
# [5 rows x 552 columns]

# %%
income_poverty_df = census_data[['NAME','POPGROUP_LABEL', 'DP03_0051E', 'DP03_0052E', 'DP03_0053E', 'DP03_0054E', 'DP03_0055E', 'DP03_0056E','DP03_0057E','DP03_0058E', 'DP03_0059E', 'DP03_0060E', 'DP03_0061E']]
income_poverty_df = income_poverty_df.rename(columns={'NAME': 'State', 'POPGROUP_LABEL': 'Race', 'DP03_0051E':'Total Household', 'DP03_0052E':'<10k', 'DP03_0053E':'10k to 15k', 'DP03_0054E':'15k to 25k', 'DP03_0055E':'25k to 35k', 'DP03_0056E':'35k to 50k','DP03_0057E': '50k to 75k','DP03_0058E': '75k to 100k', 'DP03_0059E':'100k to 150k', 'DP03_0060E':'150k to 200k', 'DP03_0061E': '200k+' })
income_poverty_df = income_poverty_df.drop(income_poverty_df.index[0])
income_poverty_df.to_csv("Output/Clean_Census.csv", index=False)
income_poverty_df.head(20)
# Out:
#                    State                                              Race  \
# 1                 Alaska                                       White alone
# 2                 Alaska                   Black or African American alone
# 3                 Alaska           American Indian and Alaska Native alone
# 4                 Alaska                                       Asian alone
# 5                 Alaska  Native Hawaiian and Other Pacific Islander alone
# 6                 Alaska                             Some Other Race alone
# 7                 Alaska                  Hispanic or Latino (of any race)
# 8   District of Columbia                                       White alone
# 9   District of Columbia                   Black or African American alone
# 10  District of Columbia           American Indian and Alaska Native alone
# 11  District of Columbia                                       Asian alone
# 12  District of Columbia                             Some Other Race alone
# 13  District of Columbia                  Hispanic or Latino (of any race)
# 14               Florida                                       White alone
# 15               Florida                   Black or African American alone
# 16               Florida           American Indian and Alaska Native alone
# 17               Florida                                       Asian alone
# 18               Florida  Native Hawaiian and Other Pacific Islander alone
# 19               Florida                             Some Other Race alone
# 20               Florida                  Hispanic or Latino (of any race)
#
#    Total Household    <10k 10k to 15k 15k to 25k 25k to 35k 35k to 50k  \
# 1           185456    6136       4307       9692      10808      17267
# 2             8458     380        211        541        715        895
# 3            28524    2363       1553       3627       2603       3395
# 4            12898     473        370        782        697       1137
# 5             2267      21          6        106         95        295
# 6             4239     206        152        264        270        645
# 7            15760     664        441        920       1190       2387
# 8           138443    4233       1294       2352       2965       4845
# 9           132384   17935       8850      11799      12113      13561
# 10            1198     116        195         59         43         74
# 11           13048    1068        296        341        345       1036
# 12            9978    1000        119        632        857        994
# 13           27098    1776        554       1272       1410       2048
# 14         5947647  304648     211855     480933     529405     747175
# 15         1117002  105750      65383     123048     130404     173524
# 16           18892    1661        993       1461       1918       2725
# 17          193040   11126       5551      12547      13356      19245
# 18            3667     357         50        405        259        424
# 19          257398   16899      10456      28156      29326      39473
# 20         1798545  116327      81438     170255     185089     248995
#
#    50k to 75k 75k to 100k 100k to 150k 150k to 200k   200k+
# 1       30886       25917        38157        19931   22355
# 2        2309        1105         1062          685     555
# 3        5251        3148         3560         1636    1388
# 4        2747        1980         2520         1387     805
# 5         669         285          460          223     107
# 6         731         632          885          291     163
# 7        3346        1985         2874         1022     931
# 8       11908       14892        26509        20163   49282
# 9       20097       15590        16105         7627    8707
# 10        424          95           87           20      85
# 11       1300        1344         2588         1544    3186
# 12       2098        1059         1404          682    1133
# 13       4414        3386         4746         2606    4886
# 14    1065249      778419       923903       410735  495325
# 15     210036      127329       115278        38213   28037
# 16       3578        2076         2724          798     958
# 17      31474       24045        34722        17387   23587
# 18        763         391          602          174     242
# 19      52539       31808        29191        10449    9101
# 20     342586      230416       240991        92386   90062
